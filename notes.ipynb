# %%
import pandas as pd
from math import *

# %%
df = pd.read_csv('notes.csv')

# %%
df.head()
# Out:
#    index note  position_right_wall  sounding_length  frequency
# 0      1    F                938.0            837.0   87.30706
# 1      2    G                927.0            826.0   97.99886
# 2      3    A                916.5            815.5  110.00000
# 3      4   Bb                902.5            801.5  116.54090
# 4      5    B                888.5            787.5  123.47080

# %%
1/(0.4*df['sounding_length'])*sqrt((3)/(pi*8746))
# Out:
# 0     0.000031
# 1     0.000032
# 2     0.000032
# 3     0.000033
# 4     0.000033
# 5     0.000034
# 6     0.000036
# 7     0.000038
# 8     0.000039
# 9     0.000041
# 10    0.000044
# 11    0.000046
# 12    0.000047
# 13    0.000050
# 14    0.000053
# 15    0.000054
# 16    0.000058
# 17    0.000061
# 18    0.000065
# 19    0.000066
# 20    0.000070
# 21    0.000075
# 22    0.000078
# 23    0.000082
# 24    0.000088
# 25    0.000093
# 26    0.000097
# 27    0.000102
# 28    0.000108
# 29    0.000115
# 30    0.000121
# 31    0.000129
# 32    0.000137
# 33    0.000146
# 34    0.000154
# 35    0.000162
# 36    0.000174
# 37    0.000186
# 38    0.000199
# 39    0.000208
# 40    0.000225
# 41    0.000239
# 42    0.000256
# 43    0.000267
# 44    0.000285
# 45    0.000307
# 46    0.000329
# Name: sounding_length, dtype: float64

# %%
df['sounding_length']
# Out:
# 0     837.0
# 1     826.0
# 2     815.5
# 3     801.5
# 4     787.5
# 5     774.5
# 6     735.0
# 7     687.0
# 8     673.0
# 9     630.0
# 10    598.0
# 11    565.0
# 12    554.0
# 13    526.0
# 14    492.0
# 15    481.5
# 16    448.0
# 17    427.5
# 18    405.0
# 19    394.5
# 20    373.0
# 21    348.5
# 22    336.5
# 23    319.5
# 24    297.0
# 25    282.0
# 26    270.5
# 27    256.5
# 28    241.5
# 29    227.5
# 30    216.5
# 31    202.0
# 32    190.0
# 33    179.5
# 34    169.5
# 35    161.0
# 36    150.5
# 37    140.5
# 38    131.0
# 39    125.5
# 40    116.0
# 41    109.5
# 42    102.0
# 43     98.0
# 44     91.5
# 45     85.0
# 46     79.5
# Name: sounding_length, dtype: float64
